# %%
# Practice 3.1
60*60
# Out:
# 3600

# %%
# Practice 3.2
seconds_per_hour = 60 * 60
print(seconds_per_hour)
# Out:
# 3600

# %%
# Practice 3.3
seconds_per_hour * 24
# Out:
# 86400

# %%
# Practice 3.4
hours_per_day = 24
seconds_per_day = seconds_per_hour * hours_per_day
print(seconds_per_day)
# Out:
# 86400

# %%
# Practice 3.5
seconds_per_day / 24
# Out:
# 3600.0

# %%
# Practice 3.6
seconds_per_day // 24
# Out:
# 3600

# %% [markdown]
# Answers in 3.5 and 3.6 were in agreement.
